# %% [markdown]
# # Run CONAN from configfile

# %%
import numpy as np
import CONAN3

# %% [markdown]
# - load configfile to generate the lightcurve, rv and setup objects.

# %%
lc_data, rv_data, mcmc = CONAN3.load_configfile(verbose=False)

# %%
lc_data
# Out:
# Object containing 1 lightcurves
# Files:['w127_pipe1.txt']
# Filepath: /home/tunde/Dropbox/postdoc/work/wasp-127/PIPE/wasp-127_conanfit/new_lcs/

# %%
lc_data.plot()

# %%
CONAN3.fit_data(lc_data,rv_data,mcmc,"max")
