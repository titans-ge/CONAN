# %% [markdown]
# # Run CONAN from configfile

# %%
import numpy as np
import CONAN3

# %% [markdown]
# - load configfile to generate the lightcurve, rv and setup objects.

# %%
lc_data, rv_data, fitter = CONAN3.load_configfile(verbose=False)

# %%
lc_data
# Out:
# Object containing 1 lightcurves
# Files:['w127_pipe_lc4.txt']
# Filepath: /home/tunde/Dropbox/postdoc/work/wasp-127/PIPE/wasp-127_conanfit/

# %%
lc_data.plot()

# %%
CONAN3.fit_data(lc_data,rv_data,fitter,"max")
# Out:
# 1
# 523
# ping
# 523
# 523
# 523
# 523
# No of dimensions:  11
# No of chains:  64
# ['T_0' 'CH1_DFocc' 'w127_pipe_lc4.txt_A0' 'w127_pipe_lc4.txt_A1'
#  'w127_pipe_lc4.txt_B1' 'w127_pipe_lc4.txt_C21' 'w127_pipe_lc4.txt_C22'
#  'w127_pipe_lc4.txt_E1' 'GPphotWN_lc1' 'GPphotscale_lc1dim3'
#  'GPphotmetric_lc1dim3']
#
# Running first burn-in...
# 100%|██████████| 20/20 [00:29<00:00,  1.52s/it]
# Running second burn-in...
# 100%|██████████| 500/500 [12:44<00:00,  1.31s/it]
# Running production...
# 100%|██████████| 1000/1000 [21:28<00:00,  1.42s/it]
# Mean acceptance fraction: 0.000
# 1
# [7297.80085467] 0.014864545548091654 0.00032605411089866156 [521.] [0.0002]
# [7297.80085467] 0.014864545548091654 0.00032605411089866156 [521.] [0.0002]
# [7297.80085467] 0.014864545548091654 0.00032605411089866156 [521.] [0.0002]
# [7297.80079521] 0.014864545548091654 0.00032605411089866156 [521.] [0.0002]
# [2504.32795664] 0.014864545548091654 0.00032605411089866156 [521.] [0.00056574]
# ...
